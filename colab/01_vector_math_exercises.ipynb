# %% [markdown]
# # Vector Mathematics — Interactive Exercises
# ## Legacy of InFest — Unit II
#
# Complete these exercises to practice vector operations used in game development.
# Run the setup cell first, then complete each exercise.

# %%
# Setup — run this cell first
import math
import random

class Vector2:
    """A simple 2D vector class for learning."""
    def __init__(self, x: float = 0.0, y: float = 0.0):
        self.x = x
        self.y = y
    
    def __add__(self, other: 'Vector2') -> 'Vector2':
        return Vector2(self.x + other.x, self.y + other.y)
    
    def __sub__(self, other: 'Vector2') -> 'Vector2':
        return Vector2(self.x - other.x, self.y - other.y)
    
    def __mul__(self, scalar: float) -> 'Vector2':
        return Vector2(self.x * scalar, self.y * scalar)
    
    def length(self) -> float:
        return math.sqrt(self.x**2 + self.y**2)
    
    def normalize(self) -> 'Vector2':
        l = self.length()
        if l == 0:
            return Vector2(0, 0)
        return Vector2(self.x / l, self.y / l)
    
    def dot(self, other: 'Vector2') -> float:
        return self.x * other.x + self.y * other.y
    
    def __repr__(self) -> str:
        return f"Vector2({self.x:.2f}, {self.y:.2f})"

print('Vector2 class loaded!')

# %% [markdown]
# ### Exercise 1: Vector Addition
#
# A player at position (3, 4) moves by a velocity of (2, -1) per frame.
# What is the new position after 1 frame? Implement your answer below.

# %%
# YOUR CODE HERE
player_pos = Vector2(3, 4)
velocity = Vector2(2, -1)

new_pos = None  # Replace with actual computation
print(f"New position: {new_pos}")

# %% [markdown]
# ### Exercise 2: Distance Between Two Points
#
# An enemy is at (10, 3) and the player is at (2, 8).
# What is the distance between them? Use `Vector2.length()`.

# %%
enemy = Vector2(10, 3)
player = Vector2(2, 8)

# Compute the distance
vec_to_player = None  # direction from enemy to player
distance = None       # length of that vector
print(f"Distance: {distance:.2f}")

# %% [markdown]
# ### Exercise 3: Normalized Direction
#
# Using the same positions, compute a unit vector pointing from the enemy toward the player.

# %%
enemy = Vector2(10, 3)
player = Vector2(2, 8)

# Compute normalized direction
direction = None
print(f"Direction: {direction}")
print(f"Check length == 1.0: {direction.length():.4f}")

# %% [markdown]
# ### Exercise 4: Dot Product & Angle
#
# Compute the dot product of Vector(1, 0) and Vector(0, 1). What does this tell you about the angle between them?
#
# Then compute the angle in degrees.

# %%
v1 = Vector2(1, 0)
v2 = Vector2(0, 1)

dot_product = None  # v1 . v2
angle_rad = None    # math.acos(dot / (|v1|*|v2|))
angle_deg = None
print(f"Dot product: {dot_product}")
print(f"Angle: {angle_deg:.0f} degrees")

# %% [markdown]
# ### Exercise 5: Following the Player
#
# Make the enemy move toward the player at speed 50 px/frame.
# Run the cell multiple times to see the enemy approach the player.

# %%
enemy = Vector2(100, 30)
player = Vector2(20, 80)
speed = 50.0

for step in range(5):
    # YOUR CODE: compute direction from enemy to player
    # YOUR CODE: normalize it
    # YOUR CODE: move enemy by direction * speed
    pass

# Check if enemy reached player
dist = (player - enemy).length()
print(f"Enemy is now at: {enemy}")
print(f"Distance to player: {dist:.2f}")
